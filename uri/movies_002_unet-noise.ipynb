# %%
from fastai import *
from fastai.vision import *
from fastai.callbacks import *
from torchvision.models import vgg16_bn
import PIL
import imageio
from superres import *

# %%
movie_data = Path('/scratch/bpho/datasets/movies_002/')
model_path = Path('/scratch/bpho/models')

# %%
def get_test_src():
    hr_tifs = movie_data/'img_hr'
    lr_tifs = movie_data/'img_lr'
    def map_to_hr(x):
        hr_name = x.relative_to(lr_tifs)
        return hr_tifs/hr_name

    train_file = list((lr_tifs/'train').iterdir())[0]
    valid_file = list((lr_tifs/'valid').iterdir())[0]
    img_files=[]
    for i in range(32): img_files.append(valid_file)
    for i in range(32): img_files.append(train_file)
    
    src = ImageImageList(img_files).split_by_idx(range(32)).label_from_func(map_to_hr)
    return src

def get_src():
    hr_tifs = movie_data/'img_hr'
    lr_tifs = movie_data/'img_lr'

    def map_to_hr(x):
        hr_name = x.relative_to(lr_tifs)
        return hr_tifs/hr_name
    
    src = (ImageImageList
            .from_folder(lr_tifs)
            .split_by_folder()
            .label_from_func(map_to_hr))
    return src

def _gaussian_noise_gray(x, gauss_sigma=1.):
    c,h,w = x.shape
    noise = torch.zeros((1,h,w))
    noise.normal_(0, gauss_sigma)
    img_max = np.minimum(1.1 * x.max(), 1.)
    x = np.minimum(np.maximum(0,x+noise.repeat((3,1,1))), img_max)
    return x

gaussian_noise_gray = TfmPixel(_gaussian_noise_gray)


def get_data(bs, size, noise=0.15):
    src = get_src()
    
    xtra_tfms = [gaussian_noise_gray(gauss_sigma=noise)]
    tfms = get_transforms(flip_vert=True, max_zoom=2,xtra_tfms=xtra_tfms )
    y_tfms = tfms
    #y_tfms = [[t for t in tfms[0]], [t for t in tfms[1]]]
    #tfms[0].append(gaussian_noise_gray(gauss_sigma=noise))
    data = (src
            .transform(tfms, size=size)
            .transform_y(y_tfms, size=size)
            .databunch(bs=bs).normalize(imagenet_stats, do_y=True))
    data.c = 3
    return data

# %%
def gram_matrix(x):
    n,c,h,w = x.size()
    x = x.view(n, c, -1)
    return (x @ x.transpose(1,2))/(c*h*w)

vgg_m = vgg16_bn(True).features.cuda().eval()
requires_grad(vgg_m, False)
blocks = [i-1 for i,o in enumerate(children(vgg_m)) if isinstance(o,nn.MaxPool2d)]

# %%
base_loss = F.l1_loss

class FeatureLoss(nn.Module):
    def __init__(self, m_feat, layer_ids, layer_wgts):
        super().__init__()
        self.m_feat = m_feat
        self.loss_features = [self.m_feat[i] for i in layer_ids]
        self.hooks = hook_outputs(self.loss_features, detach=False)
        self.wgts = layer_wgts
        self.metric_names = ['pixel',] + [f'feat_{i}' for i in range(len(layer_ids))
              ] + [f'gram_{i}' for i in range(len(layer_ids))]

    def make_features(self, x, clone=False):
        self.m_feat(x)
        return [(o.clone() if clone else o) for o in self.hooks.stored]
    
    def forward(self, input, target):
        out_feat = self.make_features(target, clone=True)
        in_feat = self.make_features(input)
        self.feat_losses = [base_loss(input,target)]
        self.feat_losses += [base_loss(f_in, f_out)*w
                             for f_in, f_out, w in zip(in_feat, out_feat, self.wgts)]
        self.feat_losses += [base_loss(gram_matrix(f_in), gram_matrix(f_out))*w**2 * 5e3
                             for f_in, f_out, w in zip(in_feat, out_feat, self.wgts)]
        self.metrics = dict(zip(self.metric_names, self.feat_losses))
        return sum(self.feat_losses)
    
    def __del__(self): self.hooks.remove()

# %%
feat_loss = FeatureLoss(vgg_m, blocks[2:5], [5,15,2])

# %%
bs = 64
size = 128
data = get_data(bs, size)
data
# Out:
# ImageDataBunch;
#
# Train: LabelList
# y: ImageItemList (1060 items)
# [Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920)]...
# Path: /scratch/bpho/datasets/movies_002/img_lr
# x: ImageImageList (1060 items)
# [Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920)]...
# Path: /scratch/bpho/datasets/movies_002/img_lr;
#
# Valid: LabelList
# y: ImageItemList (80 items)
# [Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920)]...
# Path: /scratch/bpho/datasets/movies_002/img_lr
# x: ImageImageList (80 items)
# [Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920), Image (3, 920, 920)]...
# Path: /scratch/bpho/datasets/movies_002/img_lr;
#
# Test: None

# %%
data.show_batch(3)

# %%
arch = models.resnet34
wd = 1e-3
learn = unet_learner(data, arch, wd=wd, loss_func=feat_loss, metrics=superres_metrics, 
                     callback_fns=LossMetrics, blur=True, norm_type=NormType.Weight, model_dir=model_path)
gc.collect()
# Out:
# 11923

# %%
# learn.lr_find()
# learn.recorder.plot()

# %%
lr = 1e-3

# %%
def do_fit(save_name, lrs=slice(lr), pct_start=0.9, cycle_len=10):
    learn.fit_one_cycle(cycle_len, lrs, pct_start=pct_start)
    learn.save(save_name)
    learn.show_results(rows=2, imgsize=5)

# %%
do_fit('movies_002_unet-noise.0', slice(lr*10))
# Out:
# Total time: 02:31 <p><table style='width:975px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>mse_loss</th>
#     <th>ssim</th>
#     <th>psnr</th>
#     <th>pixel</th>
#     <th>feat_0</th>
#     <th>feat_1</th>
#     <th>feat_2</th>
#     <th>gram_0</th>
#     <th>gram_1</th>
#     <th>gram_2</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>2.400298</th>
#     <th>2.643617</th>
#     <th>0.067278</th>
#     <th>0.605974</th>
#     <th>11.721293</th>
#     <th>0.172395</th>
#     <th>0.208245</th>
#     <th>0.301420</th>
#     <th>0.061891</th>
#     <th>0.584248</th>
#     <th>1.275633</th>
#     <th>0.039784</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.911014</th>
#     <th>2.741348</th>
#     <th>0.083359</th>
#     <th>0.641437</th>
#     <th>10.790500</th>
#     <th>0.244324</th>
#     <th>0.199229</th>
#     <th>0.312949</th>
#     <th>0.069737</th>
#     <th>0.560122</th>
#     <th>1.303806</th>
#     <th>0.051181</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.661157</th>
#     <th>2.477342</th>
#     <th>0.029992</th>
#     <th>0.717975</th>
#     <th>15.229980</th>
#     <th>0.122030</th>
#     <th>0.187544</th>
#     <th>0.282483</th>
#     <th>0.064685</th>
#     <th>0.502368</th>
#     <th>1.266171</th>
#     <th>0.052061</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.535451</th>
#     <th>2.411930</th>
#     <th>0.027621</th>
#     <th>0.716949</th>
#     <th>15.587608</th>
#     <th>0.110281</th>
#     <th>0.197245</th>
#     <th>0.283671</th>
#     <th>0.064199</th>
#     <th>0.498144</th>
#     <th>1.208379</th>
#     <th>0.050010</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>1.438468</th>
#     <th>2.385712</th>
#     <th>0.054742</th>
#     <th>0.797421</th>
#     <th>12.616776</th>
#     <th>0.201440</th>
#     <th>0.170121</th>
#     <th>0.274078</th>
#     <th>0.061977</th>
#     <th>0.453488</th>
#     <th>1.181924</th>
#     <th>0.042685</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>1.379747</th>
#     <th>2.518778</th>
#     <th>0.054848</th>
#     <th>0.800733</th>
#     <th>12.608425</th>
#     <th>0.218108</th>
#     <th>0.178474</th>
#     <th>0.279069</th>
#     <th>0.068752</th>
#     <th>0.484101</th>
#     <th>1.233746</th>
#     <th>0.056528</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>1.332446</th>
#     <th>2.041665</th>
#     <th>0.016523</th>
#     <th>0.851117</th>
#     <th>17.819103</th>
#     <th>0.092277</th>
#     <th>0.158468</th>
#     <th>0.250426</th>
#     <th>0.048630</th>
#     <th>0.402309</th>
#     <th>1.059650</th>
#     <th>0.029905</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>1.272845</th>
#     <th>2.340495</th>
#     <th>0.035035</th>
#     <th>0.828800</th>
#     <th>14.555026</th>
#     <th>0.176938</th>
#     <th>0.155640</th>
#     <th>0.254795</th>
#     <th>0.063974</th>
#     <th>0.432309</th>
#     <th>1.203577</th>
#     <th>0.053262</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>1.226362</th>
#     <th>2.160123</th>
#     <th>0.013555</th>
#     <th>0.822693</th>
#     <th>18.679245</th>
#     <th>0.062595</th>
#     <th>0.160863</th>
#     <th>0.259114</th>
#     <th>0.060117</th>
#     <th>0.380363</th>
#     <th>1.191811</th>
#     <th>0.045260</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>1.184558</th>
#     <th>2.116657</th>
#     <th>0.015233</th>
#     <th>0.819169</th>
#     <th>18.172232</th>
#     <th>0.066934</th>
#     <th>0.166306</th>
#     <th>0.259763</th>
#     <th>0.058443</th>
#     <th>0.378020</th>
#     <th>1.145911</th>
#     <th>0.041281</th>
#   </tr>
# </table>

# %%
learn.unfreeze()

# %%
do_fit('movies_002_unet-noise.1', slice(1e-5,lr))
# Out:
# Total time: 02:29 <p><table style='width:975px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>mse_loss</th>
#     <th>ssim</th>
#     <th>psnr</th>
#     <th>pixel</th>
#     <th>feat_0</th>
#     <th>feat_1</th>
#     <th>feat_2</th>
#     <th>gram_0</th>
#     <th>gram_1</th>
#     <th>gram_2</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.076142</th>
#     <th>2.170481</th>
#     <th>0.014549</th>
#     <th>0.814966</th>
#     <th>18.371750</th>
#     <th>0.065361</th>
#     <th>0.170559</th>
#     <th>0.264689</th>
#     <th>0.061681</th>
#     <th>0.391523</th>
#     <th>1.171397</th>
#     <th>0.045271</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.076658</th>
#     <th>2.204784</th>
#     <th>0.014589</th>
#     <th>0.813493</th>
#     <th>18.359846</th>
#     <th>0.068201</th>
#     <th>0.172003</th>
#     <th>0.266256</th>
#     <th>0.061444</th>
#     <th>0.403772</th>
#     <th>1.188455</th>
#     <th>0.044653</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.076176</th>
#     <th>2.232606</th>
#     <th>0.015236</th>
#     <th>0.809338</th>
#     <th>18.171228</th>
#     <th>0.070176</th>
#     <th>0.174378</th>
#     <th>0.267955</th>
#     <th>0.064229</th>
#     <th>0.416636</th>
#     <th>1.191088</th>
#     <th>0.048144</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.076203</th>
#     <th>2.225314</th>
#     <th>0.015673</th>
#     <th>0.820795</th>
#     <th>18.048416</th>
#     <th>0.072597</th>
#     <th>0.170546</th>
#     <th>0.264861</th>
#     <th>0.062417</th>
#     <th>0.423855</th>
#     <th>1.185220</th>
#     <th>0.045818</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>1.074334</th>
#     <th>2.300725</th>
#     <th>0.019195</th>
#     <th>0.811193</th>
#     <th>17.168133</th>
#     <th>0.089978</th>
#     <th>0.175092</th>
#     <th>0.269793</th>
#     <th>0.060182</th>
#     <th>0.469857</th>
#     <th>1.192780</th>
#     <th>0.043044</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>1.074127</th>
#     <th>2.363771</th>
#     <th>0.020917</th>
#     <th>0.806064</th>
#     <th>16.794981</th>
#     <th>0.109915</th>
#     <th>0.177359</th>
#     <th>0.276052</th>
#     <th>0.066426</th>
#     <th>0.464159</th>
#     <th>1.217864</th>
#     <th>0.051995</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>1.073415</th>
#     <th>2.198359</th>
#     <th>0.016091</th>
#     <th>0.825021</th>
#     <th>17.934311</th>
#     <th>0.074710</th>
#     <th>0.167911</th>
#     <th>0.262634</th>
#     <th>0.058198</th>
#     <th>0.434031</th>
#     <th>1.158934</th>
#     <th>0.041942</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>1.070698</th>
#     <th>2.149453</th>
#     <th>0.016204</th>
#     <th>0.836871</th>
#     <th>17.903698</th>
#     <th>0.077974</th>
#     <th>0.163549</th>
#     <th>0.257520</th>
#     <th>0.052088</th>
#     <th>0.426650</th>
#     <th>1.137449</th>
#     <th>0.034222</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>1.069458</th>
#     <th>2.292927</th>
#     <th>0.017046</th>
#     <th>0.811864</th>
#     <th>17.683781</th>
#     <th>0.081020</th>
#     <th>0.174842</th>
#     <th>0.271591</th>
#     <th>0.062287</th>
#     <th>0.456062</th>
#     <th>1.199871</th>
#     <th>0.047255</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>1.067658</th>
#     <th>2.303929</th>
#     <th>0.017193</th>
#     <th>0.813274</th>
#     <th>17.646597</th>
#     <th>0.083747</th>
#     <th>0.175912</th>
#     <th>0.273984</th>
#     <th>0.061186</th>
#     <th>0.455136</th>
#     <th>1.207968</th>
#     <th>0.045995</th>
#   </tr>
# </table>

# %%
bs = 6
size = 512
data = get_data(bs, size)

arch = models.resnet34
wd = 1e-3
learn = unet_learner(data, arch, wd=wd, loss_func=feat_loss, metrics=superres_metrics, 
                     callback_fns=LossMetrics, blur=True, norm_type=NormType.Weight, model_dir=model_path)
gc.collect()

learn = learn.load('movies_002_unet-noise.1')

# %%
do_fit('movies_002_unet-noise.2', lr)
# Out:
# Total time: 21:14 <p><table style='width:975px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>mse_loss</th>
#     <th>ssim</th>
#     <th>psnr</th>
#     <th>pixel</th>
#     <th>feat_0</th>
#     <th>feat_1</th>
#     <th>feat_2</th>
#     <th>gram_0</th>
#     <th>gram_1</th>
#     <th>gram_2</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.745323</th>
#     <th>0.965944</th>
#     <th>0.010130</th>
#     <th>0.608006</th>
#     <th>19.944607</th>
#     <th>0.062695</th>
#     <th>0.166764</th>
#     <th>0.167040</th>
#     <th>0.018327</th>
#     <th>0.288857</th>
#     <th>0.255674</th>
#     <th>0.006588</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0
th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.724752</th>
#     <th>0.849398</th>
#     <th>0.013030</th>
#     <th>0.670499</th>
#     <th>18.852213</th>
#     <th>0.065967</th>
#     <th>0.135821</th>
#     <th>0.159218</th>
#     <th>0.016630</th>
#     <th>0.227786</th>
#     <th>0.237740</th>
#     <th>0.006237</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.719316</th>
#     <th>0.901800</th>
#     <th>0.014278</th>
#     <th>0.645555</th>
#     <th>18.455084</th>
#     <th>0.070818</th>
#     <th>0.143768</th>
#     <th>0.161486</th>
#     <th>0.017179</th>
#     <th>0.260318</th>
#     <th>0.241584</th>
#     <th>0.006648</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.722056</th>
#     <th>0.914771</th>
#     <th>0.015409</th>
#     <th>0.633023</th>
#     <th>18.123932</th>
#     <th>0.077671</th>
#     <th>0.147292</th>
#     <th>0.160560</th>
#     <th>0.017132</th>
#     <th>0.269073</th>
#     <th>0.236547</th>
#     <th>0.006496</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.719812</th>
#     <th>0.895471</th>
#     <th>0.014936</th>
#     <th>0.635540</th>
#     <th>18.259594</th>
#     <th>0.073799</th>
#     <th>0.144728</th>
#     <th>0.161686</th>
#     <th>0.017328</th>
#     <th>0.252806</th>
#     <th>0.238202</th>
#     <th>0.006921</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.723555</th>
#     <th>0.859767</th>
#     <th>0.016084</th>
#     <th>0.649960</th>
#     <th>17.937790</th>
#     <th>0.075505</th>
#     <th>0.137159</th>
#     <th>0.156822</th>
#     <th>0.016595</th>
#     <th>0.234192</th>
#     <th>0.232964</th>
#     <th>0.006530</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.720893</th>
#     <th>0.878751</th>
#     <th>0.016376</th>
#     <th>0.639067</th>
#     <th>17.859539</th>
#     <th>0.074374</th>
#     <th>0.137782</th>
#     <th>0.153384</th>
#     <th>0.017099</th>
#     <th>0.261651</th>
#     <th>0.227744</th>
#     <th>0.006717</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.724232</th>
#     <th>0.867483</th>
#     <th>0.016085</th>
#     <th>0.634136</th>
#     <th>17.937298</th>
#     <th>0.078493</th>
#     <th>0.134857</th>
#     <th>0.153276</th>
#     <th>0.016084</th>
#     <th>0.249322</th>
#     <th>0.229048</th>
#     <th>0.006402</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.721200</th>
#     <th>0.864559</th>
#     <th>0.015631</th>
#     <th>0.620537</th>
#     <th>18.061625</th>
#     <th>0.069815</th>
#     <th>0.135874</th>
#     <th>0.148182</th>
#     <th>0.017421</th>
#     <th>0.263794</th>
#     <th>0.221651</th>
#     <th>0.007822</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.715611</th>
#     <th>0.856811</th>
#     <th>0.014656</th>
#     <th>0.637033</th>
#     <th>18.341677</th>
#     <th>0.070008</th>
#     <th>0.137015</th>
#     <th>0.153025</th>
#     <th>0.017279</th>
#     <th>0.247078</th>
#     <th>0.224700</th>
#     <th>0.007706</th>
#   </tr>
# </table>

# %%
bs = 2
size = 920
data = get_data(bs, size)

arch = models.resnet34
wd = 1e-3
learn = unet_learner(data, arch, wd=wd, loss_func=feat_loss, metrics=superres_metrics, 
                     callback_fns=LossMetrics, blur=True, norm_type=NormType.Weight, model_dir=model_path)
gc.collect()

learn = learn.load('movies_002_unet-noise.3')

# %%
do_fit('movies_002_unet-noise.4', lr)
# Out:
# Total time: 1:11:00 <p><table style='width:975px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>mse_loss</th>
#     <th>ssim</th>
#     <th>psnr</th>
#     <th>pixel</th>
#     <th>feat_0</th>
#     <th>feat_1</th>
#     <th>feat_2</th>
#     <th>gram_0</th>
#     <th>gram_1</th>
#     <th>gram_2</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0

# </table>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-c5b4e582226e> in <module>
# ----> 1 do_fit('movies_002_unet-noise.4', lr)
#
# <ipython-input-17-10b8c27931a3> in do_fit(save_name, lrs, pct_start, cycle_len)
#       2     learn.fit_one_cycle(cycle_len, lrs, pct_start=pct_start)
#       3     learn.save(save_name)
# ----> 4     learn.show_results(rows=3, imgsize=5)
#
# ~/repos/fastai/fastai/basic_train.py in show_results(self, ds_type, rows, **kwargs)
#     312                 preds = self.data.denorm(preds, do_x=True)
#     313         analyze_kwargs,kwargs = split_kwargs_by_func(kwargs, ds.y.analyze_pred)
# --> 314         preds = [ds.y.analyze_pred(grab_idx(preds, i), **analyze_kwargs) for i in range(rows)]
#     315         xs = [ds.x.reconstruct(grab_idx(x, i)) for i in range(rows)]
#     316         if has_arg(ds.y.reconstruct, 'x'):
#
# ~/repos/fastai/fastai/basic_train.py in <listcomp>(.0)
#     312                 preds = self.data.denorm(preds, do_x=True)
#     313         analyze_kwargs,kwargs = split_kwargs_by_func(kwargs, ds.y.analyze_pred)
# --> 314         preds = [ds.y.analyze_pred(grab_idx(preds, i), **analyze_kwargs) for i in range(rows)]
#     315         xs = [ds.x.reconstruct(grab_idx(x, i)) for i in range(rows)]
#     316         if has_arg(ds.y.reconstruct, 'x'):
#
# ~/repos/fastai/fastai/torch_core.py in grab_idx(x, i, batch_first)
#     268 def grab_idx(x,i,batch_first:bool=True):
#     269     "Grab the `i`-th batch in `x`, `batch_first` stating the batch dimension."
# --> 270     if batch_first: return ([o[i].cpu() for o in x]   if is_listy(x) else x[i].cpu())
#     271     else:           return ([o[:,i].cpu() for o in x] if is_listy(x) else x[:,i].cpu())
#     272
#
# IndexError: index 2 is out of bounds for dimension 0 with size 2

# %%
learn.unfreeze()

# %%
do_fit('movies_002_unet-noise.5', slice(1e-5,lr))
# Out:
# Total time: 1:12:45 <p><table style='width:975px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>mse_loss</th>
#     <th>ssim</th>
#     <th>psnr</th>
#     <th>pixel</th>
#     <th>feat_0</th>
#     <th>feat_1</th>
#     <th>feat_2</th>
#     <th>gram_0</th>
#     <th>gram_1</th>
#     <th>gram_2</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.671693</th>
#     <th>1.256717</th>
#     <th>0.010667</th>
#     <th>0.584962</th>
#     <th>19.727020</th>
#     <th>0.064551</th>
#     <th>0.205780</th>
#     <th>0.171839</th>
#     <th>0.019011</th>
#     <th>0.578831</th>
#     <th>0.209654</th>
#     <th>0.007052</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.667922</th>
#     <th>1.222403</th>
#     <th>0.011459</th>
#     <th>0.576600</th>
#     <th>19.415842</th>
#     <th>0.066890</th>
#     <th>0.203006</th>
#     <th>0.173644</th>
#     <th>0.019088</th>
#     <th>0.540850</th>
#     <th>0.211828</th>
#     <th>0.007097</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.672778</th>
#     <th>1.135437</th>
#     <th>0.015451</th>
#     <th>0.594118</th>
#     <th>18.116047</th>
#     <th>0.079892</th>
#     <th>0.189925</th>
#     <th>0.165799</th>
#     <th>0.018746</th>
#     <th>0.472954</th>
#     <th>0.201603</th>
#     <th>0.006519</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.671120</th>
#     <th>1.132027</th>
#     <th>0.013057</th>
#     <th>0.607131</th>
#     <th>18.847744</th>
#     <th>0.069884</th>
#     <th>0.191378</th>
#     <th>0.161949</th>
#     <th>0.018940</th>
#     <th>0.493879</th>
#     <th>0.189688</th>
#     <th>0.006309</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.667153</th>
#     <th>1.235067</th>
#     <th>0.040652</th>
#     <th>0.556230</th>
#     <th>13.913063</th>
#     <th>0.125670</th>
#     <th>0.198770</th>
#     <th>0.158243</th>
#     <th>0.017474</th>
#     <th>0.554430</th>
#     <th>0.174865</th>
#     <th>0.005615</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.670972</th>
#     <th>1.224932</th>
#     <th>0.016300</th>
#     <th>0.553177</th>
#     <th>17.883551</th>
#     <th>0.084963</th>
#     <th>0.202262</th>
#     <th>0.164833</th>
#     <th>0.022145</th>
#     <th>0.552256</th>
#     <th>0.190066</th>
#     <th>0.008407</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.676643</th>
#     <th>1.175905</th>
#     <th>0.013586</th>
#     <th>0.602515</th>
#     <th>18.674997</th>
#     <th>0.074184</th>
#     <th>0.195781</th>
#     <th>0.156593</th>
#     <th>0.018111</th>
#     <th>0.549250</th>
#     <th>0.175873</th>
#     <th>0.006113</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.668996</th>
#     <th>1.224214</th>
#     <th>0.019659</th>
#     <th>0.590486</th>
#     <th>17.070026</th>
#     <th>0.080986</th>
#     <th>0.201354</th>
#     <th>0.156967</th>
#     <th>0.017214</th>
#     <th>0.583216</th>
#     <th>0.178903</th>
#     <th>0.005573</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.671810</th>
#     <th>1.498443</th>
#     <th>0.053542</th>
#     <th>0.510451</th>
#     <th>12.719646</th>
#     <th>0.140838</th>
#     <th>0.228170</th>
#     <th>0.167832</th>
#     <th>0.019674</th>
#     <th>0.751791</th>
#     <th>0.183333</th>
#     <th>0.006804</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.666353</th>
#     <th>1.205993</th>
#     <th>0.015963</th>
#     <th>0.572161</th>
#     <th>17.974514</th>
#     <th>0.071580</th>
#     <th>0.204078</th>
#     <th>0.166105</th>
#     <th>0.017364</th>
#     <th>0.547325</th>
#     <th>0.194290</th>
#     <th>0.005250</th>
#   </tr>
# </table>

# %%
# !ls /scratch/bpho/models
# Out:
# movies_001.0.pth       movies_002_unet.4.pth	    movies_002_unet-noise.4.pth
# movies_001.1.pth       movies_002_unet.5.pth	    movies_002_unet-noise.5.pth
# movies_002_unet.0.pth  movies_002_unet-noise.0.pth  movies_rddb_001.0.pth
# movies_002_unet.1.pth  movies_002_unet-noise.1.pth  movies_rddb_001.1.pth
# movies_002_unet.2.pth  movies_002_unet-noise.2.pth  tmp.pth
# movies_002_unet.3.pth  movies_002_unet-noise.3.pth

# %%
movie_files = list((movie_data/'test').glob('*.czi'))

# %%
fn = movie_files[0]

# %%
with czifile.CziFile(fn) as czi_f:
    proc_axes, proc_shape = get_czi_shape_info(czi_f)
    channels = proc_shape['C']
    depths = proc_shape['Z']
    times = proc_shape['T']
    x,y = proc_shape['X'], proc_shape['Y']
    data = czi_f.asarray()
    preds = []
    origs = []
    idx = build_index(proc_axes, {'T': 0, 'C': 0, 'Z':0, 'X':slice(0,x),'Y':slice(0,y)})
    img = data[idx].astype(np.float32)
    img /= (img.max() * 1.5)

# %%
def image_from_tiles(learn, img, tile_sz=128, scale=4):
    pimg = PIL.Image.fromarray((img*255).astype(np.uint8), mode='L').convert('RGB')
    cur_size = pimg.size
    new_size = (cur_size[0]*scale, cur_size[1]*scale)
    in_img = Image(pil2tensor(pimg.resize(new_size, resample=PIL.Image.BICUBIC),np.float32).div_(255))
    c, w, h = in_img.shape
    
    in_tile = torch.zeros((c,tile_sz,tile_sz))
    out_img = torch.zeros((c,w,h))
    
    for x_tile in range(math.ceil(w/tile_sz)):
        for y_tile in range(math.ceil(h/tile_sz)):
            x_start = x_tile

            x_start = x_tile*tile_sz
            x_end = min(x_start+tile_sz, w)
            y_start = y_tile*tile_sz
            y_end = min(y_start+tile_sz, h)
            
            
            in_tile[:,0:(x_end-x_start), 0:(y_end-y_start)] = in_img.data[:,x_start:x_end, y_start:y_end]
            
            out_tile,_,_ = learn.predict(Image(in_tile))

            out_x_start = x_start
            out_x_end = x_end
            out_y_start = y_start
            out_y_end = y_end

            #print("out: ", out_x_start, out_y_start, ",", out_x_end, out_y_end)
            in_x_start = 0
            in_y_start = 0
            in_x_end = x_end-x_start
            in_y_end = y_end-y_start
            #print("tile: ",in_x_start, in_y_start, ",", in_x_end, in_y_end)
           
            out_img[:,out_x_start:out_x_end, out_y_start:out_y_end] = out_tile.data[:,
                                                                                  in_x_start:in_x_end, 
                                                                                  in_y_start:in_y_end]
    return out_img

# %%
def czi_predict_movie(learn, czi_in, orig_out='orig.tif', pred_out='pred.tif', size=128):
    with czifile.CziFile(czi_in) as czi_f:
        proc_axes, proc_shape = get_czi_shape_info(czi_f)
        channels = proc_shape['C']
        depths = proc_shape['Z']
        times = proc_shape['T']
        x,y = proc_shape['X'], proc_shape['Y']
        data = czi_f.asarray()
        preds = []
        origs = []
        img_max = None
        for t in progress_bar(list(range(times))):
            idx = build_index(proc_axes, {'T': t, 'C': 0, 'Z':0, 'X':slice(0,x),'Y':slice(0,y)})
            img = data[idx].astype(np.float32)
            if img_max is None: img_max = img.max() * 1.5
            img /= img_max
            out_img = image_from_tiles(learn, img, tile_sz=size).permute([1,2,0])
            pred = (out_img[None]*255).cpu().numpy().astype(np.uint8)
            preds.append(pred)
            orig = (img[None]*255).astype(np.uint8)
            origs.append(orig)

        all_y = np.concatenate(preds)
        #print(all_y.shape)
        imageio.mimwrite(pred_out, all_y) #, fps=30, macro_block_size=None) # for mp4
        all_y = np.concatenate(origs)
        #print(all_y.shape)
        imageio.mimwrite(orig_out, all_y) #, fps=30, macro_block_size=None)

# %%
bs=1
size=920
scale = 4

data = get_data(bs, size)

wd = 1e-3
learn = unet_learner(data, arch, wd=wd, loss_func=feat_loss, 
                     callback_fns=LossMetrics, blur=True, norm_type=NormType.Weight, model_dir=model_path)
gc.collect()
learn = learn.load('movies_002_unet-noise.5')

for fn in movie_files:
    pred_name = f'{fn.stem}_pred.tif'
    orig_name = f'{fn.stem}_orig.tif'
    czi_predict_movie(learn, fn, size=size, orig_out=orig_name, pred_out=pred_name )
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='300' class='' max='300', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [300/300 00:45<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 01:01<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 01:01<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='300' class='' max='300', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [300/300 00:46<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 01:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='300' class='' max='300', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [300/300 00:46<00:00]
#     </div>
